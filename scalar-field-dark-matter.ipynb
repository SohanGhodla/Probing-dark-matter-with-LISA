# %%
import matplotlib.pyplot as plt
import sympy as sp
import numpy as np
from scipy import constants 
from scipy.integrate import solve_ivp
from scipy.integrate import odeint
from matplotlib.ticker import LogLocator
from matplotlib.lines import Line2D

from scipy.special import jn  # Bessel function of the first kind
from scipy.integrate import quad  # For numerical integration

# ------- Set paramters for figures ---------
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rcParams['legend.frameon'] = False

# %%
def luminosity_distance(z):
    """Calculate the luminosity distance D_L for a given redshift z, assuming a flat ΛCDM cosmology."""
    
    pc = constants.parsec # Parsec (m)
    c = constants.c # Speed of light (m/s)

    # Flat ΛCDM Universe
    H0 = 67.4 * 1e3 / (1e6 * pc)  # Hubble constant in m/s/Mpc
    Omega_m = 0.315  # Matter density parameter
    Omega_Lambda = 0.685  # Dark energy density parameter

    # Function to integrate for comoving distance
    def integrand(z_prime):
        return 1.0 / np.sqrt(Omega_m * (1 + z_prime)**3 + Omega_Lambda)
    
    # Integrate from 0 to z to get the comoving distance
    integral, _ = quad(integrand, 0, z)
    
    # Calculate luminosity distance
    D_L = (1 + z) * (c / H0) * integral
    return D_L

def bessel_sum(n, e):
    """Calculate the sum inside the g(n, e) formula using Bessel functions."""
    term1 = jn(n - 2, n * e) - 2 * e * jn(n - 1, n * e)
    term1 += (2 / n) * jn(n, n * e) + 2 * e * jn(n + 1, n * e) - jn(n + 2, n * e)
    
    term2 = (1 - e**2) * (jn(n - 2, n * e) - 2 * jn(n, n * e) + jn(n + 2, n * e))
    
    term3 = (4 / (3 * n**2)) * jn(n, n * e)**2
    
    return term1**2 + term2**2 + term3

def g(n, e):
    """Calculate g(n, e) for the nth harmonic."""
    return (n**4 / 32) * bessel_sum(n, e)

def h_n(n, M_chirp, e, f, z=None, D_L=None):
    """
    Calculate the gravitational wave strain h_n for the nth harmonic, with two options for the distance:
    1. If D_L is supplied, use it directly.
    2. If D_L is not supplied, calculate it using the redshift z.
    
    Parameters:
    n       : Harmonic number
    M_chirp : Chirp mass in kg
    e       : Orbital eccentricity
    f       : Orbital frequency in Hz
    z       : Redshift of the source (only used if D_L is not supplied)
    D_L     : Luminosity distance in meters (optional; if provided, it overrides z)
    """

    G = constants.G # Gravitational constant (m^3/kg/s^2)
    Msun = 1.989e30  # Solar mass (kg)
    c = constants.c # Speed of light (m/s)

    # Use the supplied D_L if provided, otherwise calculate it from redshift z
    if D_L is None:
        if z is None:
            raise ValueError("Either redshift (z) or luminosity distance (D_L) must be provided.")
        # Calculate D_L using the redshift
        D_L = luminosity_distance(z)
    
    # Calculate the strain amplitude for the nth harmonic
    ecc_fac = 1 - (5/2)*e**2 + (35/24)*e**4
    strain = (8 * G**(5/3) * M_chirp**(5/3) * np.pi**(2/3) * f**(2/3)) / (5**0.5 * D_L * c**4) * ecc_fac
    
    # g(n, e) is the eccentricity-dependent term
    return strain

# %%
# Testing the above 

# Constants (in SI units)
G = constants.G # Gravitational constant (m^3/kg/s^2)
Msun = 1.989e30  # Solar mass (kg)
c = constants.c # Speed of light (m/s)
pc = constants.parsec # Parsec (m)
yr = constants.year  # seconds in yr

# Parameters
M_chirp = 12 * Msun  # Chirp mass in kg
z = 0.5               # Redshift of the source
D_L_supplied = None   # Set this to None if you want to calculate D_L from z
e = 0.                # Eccentricity of the orbit
f = 1e-3              # Orbital frequency in Hz
n = 2                 # Harmonic number (e.g., second harmonic)

# Option 1: If you know D_L (in meters), pass it directly
D_L_supplied =  8.1*1e3*pc

# Option 2: If you don't know D_L, let the function compute it from redshift z
if D_L_supplied is None:
    h = h_n(n, M_chirp, e, f, z=z)
else:
    h = h_n(n, M_chirp, e, f, D_L=D_L_supplied)

print(f"Gravitational wave strain h_{n} = {h:.3e}")
# Out:
# Gravitational wave strain h_2 = 8.260e-21

# %%
def calc_SNR(T_obs, f, m1, m2, e, z, D_L=None):
    """ Calculating SNR for the galactic (and extra galactic) sources """ 
 
    # Define parameter values
    G = constants.G # Gravitational constant (m^3/kg/s^2)
    Msun = 1.989e30  # Solar mass (kg)
    c = constants.c # Speed of light (m/s)
    pc = constants.parsec # Parsec (m)
    yr = constants.year  # seconds in yr
    
    # Fix the parameters of the confusion noise fit. This bit has been copied from Robson and Cornish 2018
    if (T_obs == 0.5):
        est = 1
    elif (T_obs == 1.0):
        est = 2
    elif (T_obs == 2.0):
        est = 3
    elif (T_obs == 4.0):
        est = 4

    # else find the closest observation period estimation
    else:
        if (T_obs < .75):
            est = 1
        elif (0.75 < T_obs and T_obs < 1.5):
            est = 2
        elif (1.5 < T_obs and T_obs < 3.0):   
            est = 3
        else:
            est = 4
            
    if (est==1):
        alpha  = 0.133
        beta   = 243.
        kappa  = 482.
        gamma  = 917.
        fk = 2.58e-3  
    elif (est==2):
        alpha  = 0.171
        beta   = 292.
        kappa  = 1020.
        gamma  = 1680.
        fk = 2.15e-3 
    elif (est==3):
        alpha  = 0.165
        beta   = 299.
        kappa  = 611.
        gamma  = 1340.
        fk = 1.73e-3  
    else:
        alpha  = 0.138
        beta   = -221.
        kappa  = 521.
        gamma  = 1680.
        fk = 1.13e-3 

    # Define the expressions for P_OMS and P_acc
    P_OMS = (1.5e-11)**2 * (1 + (2e-3 / f)**4)
    P_acc = (3e-15)**2 * (1 + (0.4e-3 / f)**2) * (1 + (f / 8e-3)**4)
    T_obs = T_obs * yr
    
    A = 9e-45 # amplitude below
    L = 2.5 * 1e9  # Value for L
    f_star = 19.09 * 1e-3  

    # Define the expression for S_c
    S_WDB = A * f**(-7/3) * np.exp(-f**alpha + beta * f * np.sin(kappa * f)) * (1 + np.tanh(gamma * (fk - f)))
    S_ins = (10 / (3 * L**2)) * (P_OMS + (4 * P_acc) / (2 * np.pi * f)**4) * (1 + (6 / 10) * (f / f_star)**2)
    S_n =  S_ins + S_WDB
   
    if D_L != None:
        D_L = D_L * pc # Distance between LISA and the galactic center (converting to parsec) 
        
    m1   = m1 * Msun
    m2   = m2 * Msun
    Mtot = m1 + m2
    mu   = m1 * m2 / Mtot
    M_chirp = mu**(3/5)*Mtot**(2/5)

    n = 2
    hn = h_n(n, M_chirp, e, f, z, D_L)
        
    SNR = hn * T_obs**(0.5) / S_n**0.5
    
    return SNR

# %%
# T = np.linspace(2,10, 100)
calc_SNR(3.5, 1e-3, 3, 29, 0., 0., 8e3)  #calc_SNR(T_obs, f, m1, m2, e, d) # supply in units of yr, Hz, Msun, Msun, kpc
# Out:
# 132.87903155386516

# %%
def velocity_c_Bulge(r):
    """
    Calculate the circular velocity  for a given radius (r) in pc using the galactic Bulge
    """
    
    G = constants.G  # Gravitational constant in m^3 kg^-1 s^-2
    M_bulge = 1.067e10  # Mass of the bulge in M_sun
    M_sun = 1.989e30
    r_b = 0.3e3  # Scale radius in parsecs
    pc = constants.parsec

    # Converting r to meters
    r_b = r_b * pc
    r = r * pc

    # Converting M_bulge to kg
    M_bulge = M_bulge * M_sun
    v_c = np.sqrt((G * M_bulge * r**2) / (r**2 + r_b**2)**(3/2))
    
    return v_c

def velocity_c_NFW(r):
    """
    Calculate the circular velocity  for a given radius (r) in pc using the NFW profile.
    """
    pc = constants.parsec # (m)
    G = constants.G # Gravitational constant in m^3 kg^-1 s^-2
    M_sun = 1.989e30

    r = r * pc
    rho_0 = 0.052 * M_sun / (pc)**3  # Characteristic density in SI units for MW. Values taken from arxiv 1906.08419
    r_s = 8.1*1e3 * pc     # Scale radius in kpc
    
    term1 = r_s / (r_s + r)
    term2 = np.log( (r_s + r) / r_s)
    v_c = np.sqrt(4 * np.pi * G * rho_0 * (r_s**3 / r) * (term1 + term2 - 1))
    return v_c

# %%
distance = 1 # [pc] from galactic center
print(f"circular velocity at {distance} pc for MW Bulge    = {velocity_c_Bulge(distance) / 1e3:.2f} [km/s]")
print(f"circular velocity at {distance} pc for MW NFW halo = {velocity_c_NFW(distance) /1e3:.2f} [km/s]")
# Out:
# circular velocity at 1 pc for MW Bulge    = 1.30 [km/s]
# circular velocity at 1 pc for MW NFW halo = 3.37 [km/s]

# %%
def Mchirp_evo(T_obs, f_in, m_ul, m10, m20, e0, r_center=None):
    """ Calculate the evolution of chirp mass as the black holes accrete mass """

    # Define parameter values
    G = constants.G  # Gravitational constant (m^3/kg/s^2)
    Msun = 1.989e30  # Solar mass (kg)
    c = constants.c  # Speed of light (m/s)
    pc = constants.parsec  # Parsec (m)
    yr = constants.year  # seconds in yr
    eV = 1.60218e-19  # electron volt in joules
    hbar = constants.hbar  # Reduced Planck's constant

    # Convert initial masses to kg and time to seconds
    m10 = m10 * Msun
    m20 = m20 * Msun
    T_obs = T_obs * yr

    # ----- Reference values ------
    M_sol_tilde = 1e10 * Msun  # reference value [kg]
    M_sol = 1e9 * Msun  # mass of Milky's soliton [kg]
    m_ul_tilde = 1e-22  # reference mass scale [eV]
    lambda_val = 2**(1/8) - 1

    # Initial conditions
    f0 = f_in
    r0 = (G * (m10 + m20) / (4 * np.pi**2 * (f0 / 2)**2))**(1 / 3)  # Kepler's third law for initial separation

    # Calculate r_c and rho_c 
    def r_c_calc(m_ul, M_sol):
        """ Calculate r_c based on the given m_ul and M_sol """
        rho_c = ((G * (m_ul * eV / c**2)**2) / (hbar**2))**3 * M_sol**4 * 0.00440
        return ((rho_c / (1.9 * Msun / pc**3))**(-1 / 4)) * (m_ul / 1e-23)**(-1 / 2) * 1e3   # Convert to pc

    def dm_dt(t, m, r_center, m_ul, M_sol):
        """ Mass accretion rate including r_center/r_c factor """
        r_c = r_c_calc(m_ul, M_sol)  # Compute r_c
        return (2.5* Msun / (1000 * yr)) * ((m / (1e9 * Msun))**2) * ((m_ul / m_ul_tilde)**6) * ((M_sol / M_sol_tilde)**4) \
               * (1 + lambda_val * (r_center / r_c)**2)**(-8)

    def dm1_dt(t, m_1, r_center):
        return dm_dt(t, m_1, r_center, m_ul, M_sol)

    def dm2_dt(t, m_2, r_center):
        return dm_dt(t, m_2, r_center, m_ul, M_sol)

    def d_mu_dt(t, m_1, m_2, r_center):
        mu = m_1 * m_2 / (m_1 + m_2)
        return dm_dt(t, mu, r_center, m_ul, M_sol)

    def dr_dt_GW(t, r, m_1, m_2, e):
        mu = m_1 * m_2 / (m_1 + m_2)
        M = m_1 + m_2
        return - (64 / 5) * (G**3 * mu * M**2) / (c**5 * r**3 * (1 - e**2)**3.5) * (1 + 73 * e**2 / 24 + 37 * e**4 / 96)

    def dr_dt_AM(t, r, m_1, m_2, e, r_center):
        mu = m_1 * m_2 / (m_1 + m_2)
        M = m_1 + m_2

        dot_m1 = dm1_dt(t, m_1, r_center)
        dot_m2 = dm2_dt(t, m_2, r_center)
        dot_mu = d_mu_dt(t, m_1, m_2, r_center)

        d_ln_mu2M_dt = (2 * dot_mu / mu) + ((dot_m1 + dot_m2) / M)

        return -r * (d_ln_mu2M_dt - 2 * e / (1 - e**2) * de_dt_AM(t, m_1, m_2, e))

    def de_dt_GW(r, m_1, m_2, e):
        mu = m_1 * m_2 / (m_1 + m_2)
        M = m_1 + m_2
        term = G**3 * mu * M**2 / (c**5 * r**4 * (1 - e**2)**(5 / 2))
        return - (304 / 15) * e * term * (1 + (121 / 304) * e**2)

    def de_dt_AM(t, m_1, m_2, e):
        M = m_1 + m_2
        dot_m1 = dm1_dt(t, m_1, r_center)
        dot_m2 = dm2_dt(t, m_2, r_center)
        return -e * (dot_m1 + dot_m2) / M

    def df_dt(t, f, m_1, m_2, r, e, r_center):
        dot_m1 = dm1_dt(t, m_1, r_center)
        dot_m2 = dm2_dt(t, m_2, r_center)
        dot_r = dr_dt_GW(t, r, m_1, m_2, e) + dr_dt_AM(t, r, m_1, m_2, e, r_center)
        M = m_1 + m_2
        return (G**(1 / 2) / (2 * np.pi)) * r**(-3 / 2) * M**(-1 / 2) * ((dot_m1 + dot_m2) - (3 * M / r) * dot_r)

    def system_of_eqs(t, y):
        m_1, m_2, r, f, e = y
        if r <= 0:
            return [0, 0, 0, 0, 0]

        dot_m1 = dm1_dt(t, m_1, r_center)
        dot_m2 = dm2_dt(t, m_2, r_center)
        dot_r = dr_dt_GW(t, r, m_1, m_2, e) + dr_dt_AM(t, r, m_1, m_2, e, r_center)

        if e > 0:
            dot_e = de_dt_GW(r, m_1, m_2, e) + de_dt_AM(t, m_1, m_2, e)
        else:
            dot_e = 0

        dot_f = df_dt(t, f, m_1, m_2, r, e, r_center)
        return [dot_m1, dot_m2, dot_r, dot_f, dot_e]

    # Time span for integration
    t_upper = (T_obs + 1 * yr)
    t_span = (0, t_upper)  # integrate from t=0 to t_upper
    y0 = [m10, m20, r0, f0, e0]  # initial conditions

    # Solve the system of differential equations
    solution = solve_ivp(system_of_eqs, t_span, y0, method='RK45', t_eval=np.linspace(0, t_upper, 1000))

    # Extract the solutions
    t_values = solution.t
    m1_values = solution.y[0]
    m2_values = solution.y[1]
    r_values = solution.y[2]
    f_values = solution.y[3]
    e_values = solution.y[4]

    # Calculate df/dt at a specific time t
    index = np.abs(t_values - T_obs).argmin()  # find the index closest to T_obs

    M_target = m1_values[index] + m2_values[index]
    r_target = r_values[index]
    f_target = f_values[index]
    e_target = e_values[index]
    df_dT_obs = df_dt(T_obs, f_target, m1_values[index], m2_values[index], r_target, e_target, r_center)

    mu_target = (m1_values[index] * m2_values[index]) / (m1_values[index] + m2_values[index])
    Mchirp = (mu_target)**(3 / 5) * (M_target)**(2 / 5)
    
    df_dt_val = df_dT_obs

    return [Mchirp / Msun, df_dt_val, r_target, f_target, e_target]

# %%
# -----------  Testing the above  (can be ignored) -----------

G = constants.G  # Gravitational constant (m^3/kg/s^2)
Msun = 1.989e30  # Solar mass (kg)
c = constants.c  # Speed of light (m/s)
pc = constants.parsec  # Parsec (m)
eV = 1.60218e-19  # electron volt in joules
hbar = constants.hbar  # Reduced Planck's constant

# ----- Reference values ------
M_sol = 1e9 * Msun  # mass of Milky's soliton [kg]
lambda_val = 2**(1/8) - 1
r_center = .01
m_ul = 1e-21
m_ul_kg = (m_ul * eV) / c**2

# Calculate r_c and rho_c 
def r_c_calc(m_ul, M_sol):
    """ Calculate r_c based on the given m_ul and M_sol """
    # Convert m_ul from eV to kg by dividing by c^2
    m_ul_kg = (m_ul * eV) / c**2
    rho_c = ((G * (m_ul_kg)**2) / (hbar**2))**3 * M_sol**4 * 0.00440
    return ((rho_c / (1.9 * Msun / pc**3))**(-1 / 4)) * (m_ul / 1e-23)**(-1 / 2) * 1e3   # Convert to pc

r_c = r_c_calc(m_ul, M_sol)  # Compute r_c

print(f'if m_ul [eV] = {m_ul:.0e} and r_center = {r_center} [pc]')
print(f'r_c = {r_c:.2e} [pc]')
print(f'rho_c = {((G * (m_ul_kg)**2) / (hbar**2))**3 * M_sol**4 * 0.00440 / (Msun) * (pc)**3: .2e} [Msun / pc^3]')
print(f'dm/dt radial factor [1 implies maximum] = {(1 + lambda_val * (r_center / r_c)**2)**(-8)}')
# Out:
# if m_ul [eV] = 1e-21 and r_center = 0.01 [pc]
# r_c = 2.28e+00 [pc]
# rho_c =  7.06e+06 [Msun / pc^3]
# dm/dt radial factor [1 implies maximum] = 0.9999860462930777

# %%
def sigma_Mchirp(SNR, T_obs, Mchirp, df_dt_val):
    """ Calculate uncertainty in chirp mass measurement """

    yr = constants.year  # seconds in yr
    T_obs = T_obs * yr
    
    sigma_Mchirp = 0.258 * (SNR / 10)**(-1) * T_obs**(-2) * Mchirp / df_dt_val
    
    return sigma_Mchirp

# %%
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f']
linestyles = ['-', '--', ':']

# %% [markdown]
# ## Figure 2 in the paper

# %%
plt.figure(figsize=(4, 3)) 

T = np.linspace(1e-1,10, 200)
yr = constants.year 
m_ul = [1e-20, 5e-20, 1e-19]  # ULDM mass

# fixed the first measurement time to t_i = 0.5 yr
f_in = 1e-3 # This f_in value if dummy. Changing it won't change result.
i = 0
m1 = 25
m2 = 25
e = 0.
t_1 = 0.5
D_L = 8.1 * 1e3 # pc 
z = 0
r_center = [0.001, 0.01] # in parsecs, the location of the black hole binary from the center of the host galaxy
r_center_latex = ['10^{-3}', '10^{-2}']

# ---------- for plotting the curves ------------
k = 0
for r_c in r_center:
    i = 0
    for m_DM in m_ul:
        del_Mch = []
        time = []
        for T_obs in T:
            if T_obs > t_1:
                delta_Mch = Mchirp_evo(T_obs, f_in, m_DM, m1, m2, e, r_c)[0]  - Mchirp_evo(t_1, f_in, m_DM, m1, m2, e, r_c)[0]  # Mchirp_evo returns [Mchirp/Msun, df_dt_val, r_target, f_target, e_target]
                
                if del_Mch[-1] >= delta_Mch:
                    break                
                else:
                    del_Mch.append(delta_Mch)
                    time.append(T_obs)
            else:
                del_Mch.append(0)
                time.append(T_obs)

        mask = np.array(time)>0.5
        plt.plot(np.array(time)[mask],np.array(del_Mch)[mask], color = colors[i], linestyle = linestyles[k])
        i +=1
    k += 1
   

# # ------ for plotting the shaded area ------------
r_c = 0.01
f = [1e-2, 5e-3, 2e-3, 1e-3]
j = 0
alp = [0.05, 0.1, 0.15, 0.2]
m_DM = 1e-20
for f_in in f:
    sig_Mchirp = []
    for i in range(len(T)):
        if i == 0:

            Mchirp = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[0]
            df_dt_val = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[1]
            f_val = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[3]
            SNR = calc_SNR(T[i], f_val, m1, m2, e, z, D_L)
    #         print(SNR)

            sig_Mchirp_val = sigma_Mchirp(SNR, T[i], Mchirp, df_dt_val)
    #         print(sig_Mchirp_val)
            sig_Mchirp.append(sig_Mchirp_val)
        else: 
            Mchirp = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[0]
            e = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[4]
            df_dt_val = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[1]
            f_val = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[3]
            SNR = calc_SNR(T[i], f_val, m1, m2, e, z, D_L)
    #         print(SNR)

            sig_Mchirp_val = sigma_Mchirp(SNR, T[i], Mchirp, df_dt_val)
    #         print(sig_Mchirp_val)
            sig_Mchirp.append(sig_Mchirp_val)

    plt.plot(T, 2 * np.array(sig_Mchirp), linestyle=':', color='k', alpha=0.35)
    plt.fill_between(T, 2 * np.array(sig_Mchirp), 10., alpha=alp[j], color='gray')
    plt.text(T[25], sig_Mchirp[52], rf'$f_{{\rm in}}$ = {f_in * 1e3:.0f} mHz', rotation=-20)
    j+=1



# plt.xlabel('time of observation [yr]', fontsize = 11)
plt.ylabel(r'$\Delta \mathcal{M} \quad [M_\odot]$', fontsize = 11)

# plt.text(3.5, 2e-11,'Detectable region (LISA)')
plt.xlim(0,10)
plt.ylim(1e-11, 10)
plt.locator_params(axis='x', nbins=6)
plt.yscale('log') 
plt.gca().yaxis.set_major_locator(LogLocator(base=10.0, numticks=6))

labels = [r"$\Theta = 10^{-8}$", r'$\Theta = 10^{-9}$', r'$\Theta = 10^{-11}$']

# Create separate legends for theta and r_center
legend_r_center = [rf"$r_{{\rm center}} = {r_c}$ pc" for r_c in r_center_latex]

from matplotlib.lines import Line2D
# Define custom line objects (solid and dashed, both black)
solid_line = Line2D([0], [0], color='black', lw=2, linestyle='-')  # Solid line
dashed_line = Line2D([0], [0], color='black', lw=2, linestyle='--')  # Dashed line
line_styles = [solid_line, dashed_line]

# Add legend for r_center with custom line styles
r_center_legend = plt.legend(line_styles, legend_r_center, loc='upper center', frameon=False, bbox_to_anchor=(0.5, 1.2), ncol = 2)
plt.gca().add_artist(r_center_legend)

labels = [r"$m_\chi = 10^{-20}$ eV", r'$m_\chi = 5 \times 10^{-20}$ eV', r'$m_\chi = 10^{-19}$ eV']
plt.legend(labels, loc='upper right', frameon=False)

# plt.savefig('galactic_scalar_field_DM_detectability.pdf', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## Figure 2 in the paper (below one has different $m_\chi$ and $r_{\rm center}$ values)

# %%
plt.figure(figsize=(4, 3)) 

T = np.linspace(1e-1,10, 200)
yr = constants.year 
m_ul = [1e-19, 5e-19, 1e-18]  # ULDM mass

# fixed the first measurement time to t_i = 0.5 yr
f_in = 1e-3 # This f_in value if dummy. Changing it won't change result.
i = 0
m1 = 25
m2 = 25
e = 0.
t_1 = 0.5
D_L = 8.1 * 1e3 # pc 
z = 0
r_center = [0.00001, 0.0001] # in parsecs, the location of the black hole binary from the center of the host galaxy
r_center_latex = ['10^{-5}', '10^{-4}']

# ---------- for plotting the curves ------------
k = 0
for r_c in r_center:
    i = 0
    for m_DM in m_ul:
        del_Mch = []
        time = []
        for T_obs in T:
            if T_obs > t_1:
                delta_Mch = Mchirp_evo(T_obs, f_in, m_DM, m1, m2, e, r_c)[0]  - Mchirp_evo(t_1, f_in, m_DM, m1, m2, e, r_c)[0]  # Mchirp_evo returns [Mchirp/Msun, df_dt_val, r_target, f_target, e_target]
                
                if del_Mch[-1] >= delta_Mch:
                    break                
                else:
                    del_Mch.append(delta_Mch)
                    time.append(T_obs)
            else:
                del_Mch.append(0)
                time.append(T_obs)

        mask = np.array(time)>0.5
        plt.plot(np.array(time)[mask],np.array(del_Mch)[mask], color = colors[i], linestyle = linestyles[k])
        i +=1
    k += 1
   

# # ------ for plotting the shaded area ------------
r_c = .0001
f = [1e-2, 5e-3, 2e-3, 1e-3]
j = 0
alp = [0.05, 0.1, 0.15, 0.2]
m_DM = 1e-19
for f_in in f:
    sig_Mchirp = []
    for i in range(len(T)):
        if i == 0:

            Mchirp = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[0]
            df_dt_val = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[1]
            f_val = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[3]
            SNR = calc_SNR(T[i], f_val, m1, m2, e, z, D_L)
    #         print(SNR)

            sig_Mchirp_val = sigma_Mchirp(SNR, T[i], Mchirp, df_dt_val)
    #         print(sig_Mchirp_val)
            sig_Mchirp.append(sig_Mchirp_val)
        else: 
            Mchirp = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[0]
            e = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[4]
            df_dt_val = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[1]
            f_val = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[3]
            SNR = calc_SNR(T[i], f_val, m1, m2, e, z, D_L)
    #         print(SNR)

            sig_Mchirp_val = sigma_Mchirp(SNR, T[i], Mchirp, df_dt_val)
    #         print(sig_Mchirp_val)
            sig_Mchirp.append(sig_Mchirp_val)

    plt.plot(T, 2 * np.array(sig_Mchirp), linestyle=':', color='k', alpha=0.35)
    plt.fill_between(T, 2 * np.array(sig_Mchirp), 10., alpha=alp[j], color='gray')
    plt.text(T[25], sig_Mchirp[52], rf'$f_{{\rm in}}$ = {f_in * 1e3:.0f} mHz', rotation=-20)
    j+=1



plt.xlabel('time of observation [yr]', fontsize = 11)
plt.ylabel(r'$\Delta \mathcal{M} \quad [M_\odot]$', fontsize = 11)

# plt.text(3.5, 2e-11,'Detectable region (LISA)')
plt.xlim(0,10)
plt.ylim(1e-11, 10)
plt.locator_params(axis='x', nbins=6)
plt.yscale('log') 
plt.gca().yaxis.set_major_locator(LogLocator(base=10.0, numticks=6))

labels = [r"$\Theta = 10^{-8}$", r'$\Theta = 10^{-9}$', r'$\Theta = 10^{-11}$']

# Create separate legends for theta and r_center
legend_r_center = [rf"$r_{{\rm center}} = {r_c}$ pc" for r_c in r_center_latex]

from matplotlib.lines import Line2D
# Define custom line objects (solid and dashed, both black)
solid_line = Line2D([0], [0], color='black', lw=2, linestyle='-')  # Solid line
dashed_line = Line2D([0], [0], color='black', lw=2, linestyle='--')  # Dashed line
line_styles = [solid_line, dashed_line]

# Add legend for r_center with custom line styles
r_center_legend = plt.legend(line_styles, legend_r_center, loc='upper center', frameon=False, bbox_to_anchor=(0.5, 1.2), ncol = 2)
plt.gca().add_artist(r_center_legend)

labels = [r"$m_\chi = 10^{-19}$ eV", r'$m_\chi = 5 \times 10^{-19}$ eV', r'$m_\chi = 10^{-18}$ eV']
plt.legend(labels, loc='lower right', frameon=False)
plt.tight_layout()

# plt.savefig('galactic_scalar_field_DM_detectability_2.pdf', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## For mass ratio = 0.1 (Figure 6 in paper)

# %%
plt.figure(figsize=(4, 3)) 

T = np.linspace(1e-1,10, 200)
yr = constants.year 
m_ul = [1e-20, 5e-20, 1e-19]  # ULDM mass

# fixed the first measurement time to t_i = 0.5 yr
f_in = 1e-3 # This f_in value if dummy. Changing it won't change result.
i = 0
m1 = 500 / 11
m2 = 50 - m1
e = 0.
t_1 = 0.5
D_L = 8.1 * 1e3 # pc 
z = 0
r_center = [0.001, 0.01] # in parsecs, the location of the black hole binary from the center of the host galaxy
r_center_latex = ['10^{-3}', '10^{-2}']

# ---------- for plotting the curves ------------
k = 0
for r_c in r_center:
    i = 0
    for m_DM in m_ul:
        del_Mch = []
        time = []
        for T_obs in T:
            if T_obs > t_1:
                delta_Mch = Mchirp_evo(T_obs, f_in, m_DM, m1, m2, e, r_c)[0]  - Mchirp_evo(t_1, f_in, m_DM, m1, m2, e, r_c)[0]  # Mchirp_evo returns [Mchirp/Msun, df_dt_val, r_target, f_target, e_target]
                
                if del_Mch[-1] >= delta_Mch:
                    break                
                else:
                    del_Mch.append(delta_Mch)
                    time.append(T_obs)
            else:
                del_Mch.append(0)
                time.append(T_obs)

        mask = np.array(time)>0.5
        plt.plot(np.array(time)[mask],np.array(del_Mch)[mask], color = colors[i], linestyle = linestyles[k])
        i +=1
    k += 1
   

# # ------ for plotting the shaded area ------------
r_c = 0.01
f = [1e-2, 5e-3, 2e-3, 1e-3]
j = 0
alp = [0.05, 0.1, 0.15, 0.2]
m_DM = 1e-20
for f_in in f:
    sig_Mchirp = []
    for i in range(len(T)):
        if i == 0:

            Mchirp = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[0]
            df_dt_val = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[1]
            f_val = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[3]
            SNR = calc_SNR(T[i], f_val, m1, m2, e, z, D_L)
    #         print(SNR)

            sig_Mchirp_val = sigma_Mchirp(SNR, T[i], Mchirp, df_dt_val)
    #         print(sig_Mchirp_val)
            sig_Mchirp.append(sig_Mchirp_val)
        else: 
            Mchirp = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[0]
            e = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[4]
            df_dt_val = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[1]
            f_val = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[3]
            SNR = calc_SNR(T[i], f_val, m1, m2, e, z, D_L)
    #         print(SNR)

            sig_Mchirp_val = sigma_Mchirp(SNR, T[i], Mchirp, df_dt_val)
    #         print(sig_Mchirp_val)
            sig_Mchirp.append(sig_Mchirp_val)

    plt.plot(T, 2 * np.array(sig_Mchirp), linestyle=':', color='k', alpha=0.35)
    plt.fill_between(T, 2 * np.array(sig_Mchirp), 10., alpha=alp[j], color='gray')
    plt.text(T[20], sig_Mchirp[52], rf'$f_{{\rm in}}$ = {f_in * 1e3:.0f} mHz', rotation=-20)
    j+=1



# plt.xlabel('time of observation [yr]', fontsize = 11)
plt.ylabel(r'$\Delta \mathcal{M} \quad [M_\odot]$', fontsize = 11)

# plt.text(3.5, 2e-11,'Detectable region (LISA)')
plt.xlim(0,10)
plt.ylim(1e-11, 10)
plt.locator_params(axis='x', nbins=6)
plt.yscale('log') 
plt.gca().yaxis.set_major_locator(LogLocator(base=10.0, numticks=6))

labels = [r"$\Theta = 10^{-8}$", r'$\Theta = 10^{-9}$', r'$\Theta = 10^{-11}$']

# Create separate legends for theta and r_center
legend_r_center = [rf"$r_{{\rm center}} = {r_c}$ pc" for r_c in r_center_latex]

from matplotlib.lines import Line2D
# Define custom line objects (solid and dashed, both black)
solid_line = Line2D([0], [0], color='black', lw=2, linestyle='-')  # Solid line
dashed_line = Line2D([0], [0], color='black', lw=2, linestyle='--')  # Dashed line
line_styles = [solid_line, dashed_line]

# Add legend for r_center with custom line styles
r_center_legend = plt.legend(line_styles, legend_r_center, loc='upper center', frameon=False, bbox_to_anchor=(0.5, 1.2), ncol = 2)
plt.gca().add_artist(r_center_legend)

labels = [r"$m_\chi = 10^{-20}$ eV", r'$m_\chi = 5 \times 10^{-20}$ eV', r'$m_\chi = 10^{-19}$ eV']
plt.legend(labels, loc='upper right', frameon=False)

# plt.savefig('galactic_scalar_field_DM_detectability_mass_ratio_pt1.pdf', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## mass ratio = 0.1 (Figure 6 in paper)

# %%
plt.figure(figsize=(4, 3))  
T = np.linspace(1e-1,10, 200)
yr = constants.year 
m_ul = [1e-19, 5e-19, 1e-18]  # DM dimensionless temperature

# fixed the first measurement time to t_i = 0.5 yr
f_in = 1e-3 # This f_in value if dummy. Changing it won't change result.
i = 0
m1 = 500 / 11
m2 = 50 - m1
e = 0.
t_1 = 0.5
D_L = 8.1 * 1e3 # pc 
z = 0
r_center = [0.00001, 0.0001] # in parsecs, the location of the black hole binary from the center of the host galaxy
r_center_latex = ['10^{-5}', '10^{-4}']

# ---------- for plotting the curves ------------
k = 0
for r_c in r_center:
    i = 0
    for m_DM in m_ul:
        del_Mch = []
        time = []
        for T_obs in T:
            if T_obs > t_1:
                delta_Mch = Mchirp_evo(T_obs, f_in, m_DM, m1, m2, e, r_c)[0]  - Mchirp_evo(t_1, f_in, m_DM, m1, m2, e, r_c)[0]  # Mchirp_evo returns [Mchirp/Msun, df_dt_val, r_target, f_target, e_target]
                
                if del_Mch[-1] >= delta_Mch:
                    break                
                else:
                    del_Mch.append(delta_Mch)
                    time.append(T_obs)
            else:
                del_Mch.append(0)
                time.append(T_obs)

        mask = np.array(time)>0.5
        plt.plot(np.array(time)[mask],np.array(del_Mch)[mask], color = colors[i], linestyle = linestyles[k])
        i +=1
    k += 1
   

# # ------ for plotting the shaded area ------------
r_c = .0001
f = [1e-2, 5e-3, 2e-3, 1e-3]
j = 0
alp = [0.05, 0.1, 0.15, 0.2]
m_DM = 1e-19
for f_in in f:
    sig_Mchirp = []
    for i in range(len(T)):
        if i == 0:

            Mchirp = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[0]
            df_dt_val = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[1]
            f_val = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[3]
            SNR = calc_SNR(T[i], f_val, m1, m2, e, z, D_L)
    #         print(SNR)

            sig_Mchirp_val = sigma_Mchirp(SNR, T[i], Mchirp, df_dt_val)
    #         print(sig_Mchirp_val)
            sig_Mchirp.append(sig_Mchirp_val)
        else: 
            Mchirp = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[0]
            e = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[4]
            df_dt_val = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[1]
            f_val = Mchirp_evo(T[i], f_in, m_DM, m1, m2, e, r_c)[3]
            SNR = calc_SNR(T[i], f_val, m1, m2, e, z, D_L)
    #         print(SNR)

            sig_Mchirp_val = sigma_Mchirp(SNR, T[i], Mchirp, df_dt_val)
    #         print(sig_Mchirp_val)
            sig_Mchirp.append(sig_Mchirp_val)

    plt.plot(T, 2 * np.array(sig_Mchirp), linestyle=':', color='k', alpha=0.35)
    plt.fill_between(T, 2 * np.array(sig_Mchirp), 10., alpha=alp[j], color='gray')
    plt.text(T[20], sig_Mchirp[52], rf'$f_{{\rm in}}$ = {f_in * 1e3:.0f} mHz', rotation=-20)
    j+=1



plt.xlabel('time of observation [yr]', fontsize = 11)
plt.ylabel(r'$\Delta \mathcal{M} \quad [M_\odot]$', fontsize = 11)

# plt.text(3.5, 2e-11,'Detectable region (LISA)')
plt.xlim(0,10)
plt.ylim(1e-11, 10)
plt.locator_params(axis='x', nbins=6)
plt.yscale('log') 
plt.gca().yaxis.set_major_locator(LogLocator(base=10.0, numticks=6))

labels = [r"$\Theta = 10^{-8}$", r'$\Theta = 10^{-9}$', r'$\Theta = 10^{-11}$']

# Create separate legends for theta and r_center
legend_r_center = [rf"$r_{{\rm center}} = {r_c}$ pc" for r_c in r_center_latex]

from matplotlib.lines import Line2D
# Define custom line objects (solid and dashed, both black)
solid_line = Line2D([0], [0], color='black', lw=2, linestyle='-')  # Solid line
dashed_line = Line2D([0], [0], color='black', lw=2, linestyle='--')  # Dashed line
line_styles = [solid_line, dashed_line]

# Add legend for r_center with custom line styles
r_center_legend = plt.legend(line_styles, legend_r_center, loc='upper center', frameon=False, bbox_to_anchor=(0.5, 1.2), ncol = 2)
plt.gca().add_artist(r_center_legend)

labels = [r"$m_\chi = 10^{-19}$ eV", r'$m_\chi = 5 \times 10^{-19}$ eV', r'$m_\chi = 10^{-18}$ eV']
plt.legend(labels, loc='lower right', frameon=False)

# plt.tight_layout()
# plt.savefig('galactic_scalar_field_DM_detectability_mass_ratio_pt1_2.pdf', bbox_inches = 'tight')
plt.show()

# %%
# Exercise relavant to the paper
M = 4.3*1e6 * Msun
print(f'Swarzschild radius for {M/Msun: .1e} Msun black hole = {2 * G * M / c**2 / pc:.2e} pc')
# Out:
# Swarzschild radius for  4.3e+06 Msun black hole = 4.12e-07 pc

# %%
def gw_merger_time(m1_solar_masses, m2_solar_masses, f, e):
    """
    Calculate the merger time for an eccentric binary system using the fitting formula from Ilya Mandel 2021.

    Parameters:
    m1_solar_masses (float): Mass of the first black hole in solar masses.
    m2_solar_masses (float): Mass of the second black hole in solar masses.
    f (float): Initial orbital frequency of the binary system in Hz.
    e (float): Initial eccentricity of the binary system.

    Returns:
    float: Merger time in years.
    """
    # Constants
    Msun = 1.989 * 1e30  # Solar mass in kg
    G = constants.G  # Gravitational constant
    c = constants.c  # Speed of light
    yr = constants.year
    
    # Convert masses from solar masses to kg
    m1 = m1_solar_masses * Msun
    m2 = m2_solar_masses * Msun

    # Compute the initial semi-major axis using Kepler's third law (for initial circular orbit approximation)
    a0 = (G * (m1 + m2) / (4 * np.pi**2 * (f / 2)**2))**(1 / 3)

    # Calculate beta
    beta = (64 / 5) * (G**3 * m1 * m2 * (m1 + m2)) / (c**5)

    # Calculate merger time for circular binary (Tc)
    Tc_circular = (a0**4) / (4 * beta)

    # Apply the fitting formula for eccentric binaries
    eccentric_factor = (1 + 0.27 * e**10 + 0.33 * e**20 + 0.2 * e**1000) * (1 - e**2)**(7 / 2)
    Tc_eccentric = Tc_circular * eccentric_factor

    # Convert merger time from seconds to years
    Tc_years_eccentric = Tc_eccentric / yr

    return Tc_years_eccentric

# test usage:
m1 = 36  # Mass of first black hole in solar masses
m2 = 29  # Mass of second black hole in solar masses
f = 1e-2  # Initial orbital frequency in Hz
e = 0.5  # Initial eccentricity

merger_time = gw_merger_time(m1, m2, f, e)
print(f"merger time = {merger_time:.2e} years.")
# Out:
# merger time = 6.22e+00 years.

# %% [markdown]
# ## The below is a test case (for calculation check) and can be ignored

# %%
plt.figure(figsize=(5, 4)) 

M_arr = np.logspace(1, 3.8, 100)
m_ul = np.logspace(-20, -18, 20)
# yr = 365.25*24*3600

f_in = [1e-3, 3e-3, 6e-3]
D_L = 5e7
z = 0.
e = 0.
t_1 = 4
T_obs = t_1 + 0.1
rc = 0.001 # pc

i=0
for f in f_in:
    Min_M_for_m_DM = []
    for m_DM in m_ul:
        Flag = 0
        for M in M_arr:
            m1 = M * 10/11
            m2 = M - m1
            t_merge = gw_merger_time(m1, m2, f, e)
            # t_merge = 11
        
            if t_merge > T_obs:
                delta_Mch = Mchirp_evo(T_obs, f, m_DM, m1, m2, e, rc)[0]  - Mchirp_evo(t_1, f, m_DM, m1, m2, e, rc)[0] # Mchirp_evo returns [Mchirp/Msun, df_dt_val, r_target, f_target, e_target]
                df_dt_val = Mchirp_evo(t_1, f, m_DM, m1, m2, e, rc)[1]
                f_val = Mchirp_evo(t_1, f, m_DM, m1, m2, e, rc)[3]
                Mchirp = Mchirp_evo(t_1, f, m_DM, m1, m2, e, rc)[0]
                
                SNR = calc_SNR(t_1, f_val, m1, m2, e, z, D_L)
                sig_Mchirp_val = sigma_Mchirp(SNR, t_1, Mchirp, df_dt_val)

                if delta_Mch >= 2 * sig_Mchirp_val:
                    Min_M_for_m_DM.append(M)
                    Flag = 1
                    # print('y')
                    break 
            # else:
            #     print('merges early', rf'{m1:.2f}', m2, rf'{th:.2e}')

        if Flag == 0:
            Min_M_for_m_DM.append(np.max(M_arr))

    plt.plot(m_ul, Min_M_for_m_DM, color = colors[i])
    plt.fill_between(m_ul, Min_M_for_m_DM, y2=max(M_arr), where=(Min_M_for_m_DM < max(M_arr)), \
                                            alpha=0.2, color = colors[i],label = '$f = 1$ mHz')
    i+=1

# plt.xlim(4e-11, 5e-8)
plt.yscale('log') 
plt.xscale('log')
plt.xlabel(r'$m_\chi$ [eV]')
plt.ylabel(r'$M_{\rm total} \quad [M_\odot]$')
plt.legend(f_in)

# plt.savefig('extagalactic_scalar_field_DM_detectability.pdf', bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ## Figure 3 in the paper

# %%
M_arr = np.logspace(1, 3.8, 160)
m_ul = np.logspace(-20.1, -18, 80)
f_in = [7e-4, 1e-3, 4e-3]
D_L_values = [1e6, 1e7, 1e8, 1e9]
D_L_latex = [r'$10^6$', r'$10^7$', r'$10^8$', r'$10^9$']  # Correct LaTeX representation for distances
f_in_latex = [r'$f_{\rm in} = 0.7 \, \mathrm{mHz}$', r'$f_{\rm in} = 1 \, \mathrm{mHz}$', r'$f_{\rm in} = 4 \, \mathrm{mHz}$']
# f_in_latex = [r'$7 \times 10^{-4} \, \mathrm{Hz}$', r'$1 \times 10^{-3} \, \mathrm{Hz}$', r'$4 \times 10^{-3} \, \mathrm{Hz}$']  # Correct LaTeX representation for frequencies
t_1_values = [3.9, 9.9]  # In years
z = 0
e = 0
T_obs_offset = 0.1
rc = 0.0001  # pc
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']  # Define some colors for the different f_in values
line_styles = ['-', '--']  # Solid and dashed lines for the two t_1 values


# Create a figure with 2x2 subplots
fig, axes = plt.subplots(2, 2, figsize=(8, 6))
axes = axes.flatten()  # Flatten to easily iterate over

# Iterate over D_L values and create subplots
for idx, D_L in enumerate(D_L_values):
    ax = axes[idx]
    
    for t_idx, t_1 in enumerate(t_1_values):
        T_obs = t_1 + T_obs_offset
        i = 0
        
        for f in f_in:
            Min_M_for_m_DM = []  # Minimum M values for plotting
            Max_M_for_m_DM = []  # Maximum M values for fill area
            valid_m_ul = []  # Corresponding m_DM values

            for m_DM in m_ul:
                Flag = 0  # Reset flag for each m_DM
                min_M = None  # Store first valid M
                max_M = None  # Store upper bound for fill

                for M in M_arr:
                    m1 = M / 2
                    m2 = M / 2
                    t_merge = gw_merger_time(m1, m2, f, e)

                    if t_merge > T_obs:
                        delta_Mch = Mchirp_evo(T_obs, f, m_DM, m1, m2, e, rc)[0] - \
                                    Mchirp_evo(t_1, f, m_DM, m1, m2, e, rc)[0]
                        df_dt_val = Mchirp_evo(t_1, f, m_DM, m1, m2, e, rc)[1]
                        f_val = Mchirp_evo(t_1, f, m_DM, m1, m2, e, rc)[3]
                        Mchirp = Mchirp_evo(t_1, f, m_DM, m1, m2, e, rc)[0]

                        SNR = calc_SNR(t_1, f_val, m1, m2, e, z, D_L)
                        sig_Mchirp_val = sigma_Mchirp(SNR, t_1, Mchirp, df_dt_val)

                        # Store minimum M only when the condition is first met
                        if delta_Mch >= 2 * sig_Mchirp_val and Flag == 0:
                            min_M = M  # Store first valid M
                            Flag = 1

                        # Continue collecting max_M while t_merge > T_obs
                        if Flag == 1:
                            max_M = M  # Store upper bound for fill
                    else:
                        # Stop collecting once t_merge <= T_obs
                        break

                # Store results if a valid M was found
                if min_M is not None and max_M is not None:
                    Min_M_for_m_DM.append(min_M)
                    Max_M_for_m_DM.append(max_M)
                    valid_m_ul.append(m_DM)

            # Plot only if we have valid points
            if Min_M_for_m_DM:
                # Convert to numpy arrays for consistency
                valid_m_ul = np.array(valid_m_ul)
                Min_M_for_m_DM = np.array(Min_M_for_m_DM)
                Max_M_for_m_DM = np.array(Max_M_for_m_DM)

                # Set alpha values based on t_obs (t_idx: 0 for 4 years, 1 for 10 years)
                alpha_value = 0.15 if t_idx == 0 else 0.1

                # Plot the minimum M values
                ax.plot(valid_m_ul, Min_M_for_m_DM, color=colors[i], linestyle=line_styles[t_idx])

                # Fill the area between Min_M and Max_M
                ax.fill_between(valid_m_ul, Min_M_for_m_DM, Max_M_for_m_DM, 
                                where=(Min_M_for_m_DM < Max_M_for_m_DM), 
                                alpha=alpha_value, color=colors[i])

            i += 1

    # Customize each subplot
    ax.set_ylim(10,)
    ax.set_xlim(6e-21, 7e-19)
    ax.set_xscale('log')
    ax.set_yscale('log')
    if idx == 0:
        ax.text(0.4, 0.05, r'$r_{\rm center} = 10^{-4}$ pc', horizontalalignment='right', verticalalignment='bottom', 
            transform=ax.transAxes, fontsize = 12)
    if idx > 1:
        ax.set_xlabel(r'$m_\chi$ [eV]', fontsize = 12)
    if idx == 0 or idx == 2:
        ax.set_ylabel(r'$M \quad [M_\odot]$', fontsize = 12)

    # Add the distance in scientific notation at the lower right-hand side of each plot
    ax.text(0.95, 0.05, f'$D_L$ = {D_L_latex[idx]} pc', 
            horizontalalignment='right', verticalalignment='bottom', 
            transform=ax.transAxes, fontsize = 12)

# Add legends only to the first subplot (axes[3])
frequency_legend_elements = [Line2D([0], [0], color=colors[i], lw=2, label=f_in_latex[i]) for i in range(len(f_in))]
legend1 = axes[3].legend(handles=frequency_legend_elements, loc='center left', frameon=False, fontsize = 12)

# Custom legend for line styles representing t_1 values
line_style_legend_elements = [Line2D([0], [0], color='black', linestyle=line_styles[i], lw=2, label=r'$T_{\rm obs}$' + f' = {T_obs} yr') for i, T_obs in enumerate([4, 10])]
legend2 = axes[3].legend(handles=line_style_legend_elements, loc='lower left', frameon=False, fontsize = 12)

# Add the first legend back using ax.add_artist so it doesn't get replaced
axes[3].add_artist(legend1)

# Adjust layout to prevent overlap
plt.tight_layout()

plt.savefig('extagalactic_scalar_field_DM_detectability.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Figure 7 in the paper (mass-ratio = 0.1)

# %%
M_arr = np.logspace(1, 3.8, 160)
m_ul = np.logspace(-20.1, -18, 80)
f_in = [7e-4, 1e-3, 4e-3]
D_L_values = [1e6, 1e7, 1e8, 1e9]
D_L_latex = [r'$10^6$', r'$10^7$', r'$10^8$', r'$10^9$']  #  LaTeX representation for distances
f_in_latex = [r'$f_{\rm in} = 0.7 \, \mathrm{mHz}$', r'$f_{\rm in} = 1 \, \mathrm{mHz}$', r'$f_{\rm in} = 4 \, \mathrm{mHz}$']
# f_in_latex = [r'$7 \times 10^{-4} \, \mathrm{Hz}$', r'$1 \times 10^{-3} \, \mathrm{Hz}$', r'$4 \times 10^{-3} \, \mathrm{Hz}$']  #  LaTeX representation for frequencies

t_1_values = [3.9, 9.9]  # In years
z = 0
e = 0
T_obs_offset = 0.1
rc = 0.0001  # pc
colors = ['#1f77b4', '#ff7f0e', '#2ca02c']  # colors for the different f_in values
line_styles = ['-', '--']  # Solid and dashed lines for the two t_1 values


fig, axes = plt.subplots(2, 2, figsize=(8, 6))
axes = axes.flatten()  # Flatten to easily iterate over

# Iterate over D_L values and create subplots
for idx, D_L in enumerate(D_L_values):
    ax = axes[idx]
    
    for t_idx, t_1 in enumerate(t_1_values):
        T_obs = t_1 + T_obs_offset
        i = 0
        
        for f in f_in:
            Min_M_for_m_DM = []  # Minimum M values for plotting
            Max_M_for_m_DM = []  # Maximum M values for fill area
            valid_m_ul = []  # Corresponding m_DM values

            for m_DM in m_ul:
                Flag = 0  # Reset flag for each m_DM
                min_M = None  # Store first valid M
                max_M = None  # Store upper bound for fill

                for M in M_arr:
                    m1 = M * 10/11
                    m2 = M - m1
                    t_merge = gw_merger_time(m1, m2, f, e)

                    if t_merge > T_obs:
                        delta_Mch = Mchirp_evo(T_obs, f, m_DM, m1, m2, e, rc)[0] - \
                                    Mchirp_evo(t_1, f, m_DM, m1, m2, e, rc)[0]
                        df_dt_val = Mchirp_evo(t_1, f, m_DM, m1, m2, e, rc)[1]
                        f_val = Mchirp_evo(t_1, f, m_DM, m1, m2, e, rc)[3]
                        Mchirp = Mchirp_evo(t_1, f, m_DM, m1, m2, e, rc)[0]

                        SNR = calc_SNR(t_1, f_val, m1, m2, e, z, D_L)
                        sig_Mchirp_val = sigma_Mchirp(SNR, t_1, Mchirp, df_dt_val)

                        # Store minimum M only when the condition is first met
                        if delta_Mch >= 2 * sig_Mchirp_val and Flag == 0:
                            min_M = M  # Store first valid M
                            Flag = 1

                        # Continue collecting max_M while t_merge > T_obs
                        if Flag == 1:
                            max_M = M  # Store upper bound for fill
                    else:
                        # Stop collecting once t_merge <= T_obs
                        break

                # Store results if a valid M was found
                if min_M is not None and max_M is not None:
                    Min_M_for_m_DM.append(min_M)
                    Max_M_for_m_DM.append(max_M)
                    valid_m_ul.append(m_DM)

            # Plot only if we have valid points
            if Min_M_for_m_DM:
                # Convert to numpy arrays for consistency
                valid_m_ul = np.array(valid_m_ul)
                Min_M_for_m_DM = np.array(Min_M_for_m_DM)
                Max_M_for_m_DM = np.array(Max_M_for_m_DM)

                # Set alpha values based on t_obs (t_idx: 0 for 4 years, 1 for 10 years)
                alpha_value = 0.15 if t_idx == 0 else 0.1

                # Plot the minimum M values
                ax.plot(valid_m_ul, Min_M_for_m_DM, color=colors[i], linestyle=line_styles[t_idx])

                # Fill the area between Min_M and Max_M
                ax.fill_between(valid_m_ul, Min_M_for_m_DM, Max_M_for_m_DM, 
                                where=(Min_M_for_m_DM < Max_M_for_m_DM), 
                                alpha=alpha_value, color=colors[i])

            i += 1

    # Customize each subplot
    ax.set_ylim(10,)
    ax.set_xlim(6e-21, 7e-19)
    ax.set_xscale('log')
    ax.set_yscale('log')
    if idx == 0:
        ax.text(0.4, 0.05, r'$r_{\rm center} = 10^{-4}$ pc', horizontalalignment='right', verticalalignment='bottom', 
            transform=ax.transAxes, fontsize = 12)
    if idx > 1:
        ax.set_xlabel(r'$m_\chi$ [eV]', fontsize = 12)
    if idx == 0 or idx == 2:
        ax.set_ylabel(r'$M \quad [M_\odot]$', fontsize = 12)

    # Add the distance in scientific notation at the lower right-hand side of each plot
    ax.text(0.95, 0.05, f'$D_L$ = {D_L_latex[idx]} pc', 
            horizontalalignment='right', verticalalignment='bottom', 
            transform=ax.transAxes, fontsize = 12)

# Add legends only to the first subplot (axes[3])
frequency_legend_elements = [Line2D([0], [0], color=colors[i], lw=2, label=f_in_latex[i]) for i in range(len(f_in))]
legend1 = axes[3].legend(handles=frequency_legend_elements, loc='center left', frameon=False, fontsize = 12)

# Custom legend for line styles representing t_1 values
line_style_legend_elements = [Line2D([0], [0], color='black', linestyle=line_styles[i], lw=2, label=r'$T_{\rm obs}$' + f' = {T_obs} yr') for i, T_obs in enumerate([4, 10])]
legend2 = axes[3].legend(handles=line_style_legend_elements, loc='lower left', frameon=False, fontsize = 12)

# Add the first legend back using ax.add_artist so it doesn't get replaced
axes[3].add_artist(legend1)

plt.tight_layout()

plt.savefig('extagalactic_scalar_field_DM_detectability_q_pt1.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Figure 4 in paper

# %%
# Define constants
G = constants.G  # Gravitational constant (m^3/kg/s^2)
Msun = 1.989e30 
c = constants.c  
pc = constants.parsec  
yr = constants.year  
lambda_ = 1.12  
gamma = 1  # Polytropic index

# Define theta values for dark matter case
theta_values = [1e-9, 1e-10]
theta_val_latex = ['10^{-9}', '10^{-10}']

# Baryonic matter parameters
m_H = 1.671e-27  # kg
c_s_baryonic = np.sqrt(1 * (1.38e-23) * (100) / m_H)

# Define dark matter density near the galactic center
rho_0 = 0.052 * Msun / (pc)**3
r_earth = 8.1 * 1e3  # LISA's location in parsecs

# Time array (in seconds)
t = np.logspace(-1, 8.5, num=5000, base=10)

# Masses to be considered
mass_values = [100, 1000]  # in Msun

# Define r values (in parsec) and corresponding colors
r_values = [1, 10]  # in parsec
r_colors = ['#1f77b4', '#ff7f0e']  # Blue for 1 pc, Orange for 10 pc

# Define line styles for different theta values
linestyles_theta = ['-', '--']  # Solid for theta=1e-9, Dashed for theta=1e-10

# Baryonic matter colors
baryonic_colors = ['#2ca02c', '#d62728']  # 'k', 'gray', 

# Adjust the figure size to allow space for the legend at the top
fig, axs = plt.subplots(1, 2, figsize=(8, 3))  # Original figure size

# Loop over the masses (m_i = 100 and m_i = 1000)
for idx, (m_i, ax) in enumerate(zip(mass_values, axs)):
    # Plot for dark matter accretion with two r and two theta values
    for r_idx, r in enumerate(r_values):
        color = r_colors[r_idx]
        v_inf = velocity_c_NFW(r)  # Calculate v_inf using the NFW profile
        rho_inf = rho_0 / (r / r_earth) / (1 + (r / r_earth)**2)

        for th_idx, theta in enumerate(theta_values):
            linestyle = linestyles_theta[th_idx]
            c_s = np.sqrt(gamma * theta * c**2)
            alpha = 4 * np.pi * lambda_ * G**2 * rho_inf / (c_s**2 + v_inf**2)**1.5
            denominator = m_i * Msun * alpha * t - 1
            y_dark = -1 / denominator - 1  # Simplified expression

            label = f'DM: $\\Theta_\\infty = {theta_val_latex[th_idx]}$, ' +  r'$r_{\rm center} = $' + f'{r} pc'
            ax.plot(t / yr, y_dark, label=label, color=color, linestyle=linestyle)

    # Baryonic case overplotted for n_H = 50 and n_H = 1
    nH_values = [50, 1]
    for nH, color in zip(nH_values, baryonic_colors):
        rho_baryonic = nH * m_H / (1e-2)**3
        alpha_baryonic = 4 * np.pi * lambda_ * G ** 2 * rho_baryonic / c_s_baryonic**3
        denominator_bm = m_i * Msun * alpha_baryonic * t - 1
        # y_baryonic = -m_i * Msun / (m_i * Msun * alpha_baryonic * t - 1) / (m_i*Msun) - 1 

        y_baryonic = -1 / denominator_bm - 1  

        label = f'BM: $n_H = {nH}$ cm$^{{-3}}$'
        ax.plot(t / yr, y_baryonic, label=label, color=color, alpha = 0.7)

    ax.set_yscale('log')
    ax.set_ylim(1e-10, 5e-5)
    ax.set_xlabel('$t$  [yr]')
    ax.set_ylabel('$\Delta m / m_i$')
    ax.yaxis.set_major_locator(LogLocator(base=10.0, numticks=6))  # numticks controls the number of ticks
    ax.text(0, 1e-5, f'$m_i = {m_i} \\, M_\\odot$', fontsize=10)

handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', fontsize=9, frameon=False, ncol=3, bbox_to_anchor=(0.535, 1.15))

plt.tight_layout() 
plt.savefig('DM_vs_BM_accretion.pdf', bbox_inches='tight')

plt.show()
